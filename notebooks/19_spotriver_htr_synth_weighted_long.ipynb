# %% [raw]
# ---
# title: "River Hyperparameter Tuning with SPOT HTR"
# format: html
# ---

# %% [markdown]
# # Sequential Parameter Optimization
# ## `river` Hyperparameter Tuning: HTR with User Data

# %%
pip list | grep spot
# Out:
# pyspot                                    0.0.1
# pyspotriver                               0.0.3
# pyspotstream                              0.2.0
# spotPython                                0.0.11
# spotRiver                                 0.0.13
# Note: you may need to restart the kernel to use updated packages.

# %%
# import sys
# !{sys.executable} -m pip install --upgrade build
# !{sys.executable} -m pip install --upgrade --force-reinstall http://www.gm.fh-koeln.de/~bartz/site/spotPython.tar.gz

# %% [markdown]
# ## Example 1: HTR Hyperparameter

# %%
import numpy as np
from math import inf
from spotRiver.fun.hyperriver import HyperRiver
from spotPython.spot import spot
from spotRiver import data
from scipy.optimize import shgo
from scipy.optimize import direct
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt
from spotRiver.utils.selectors import select_leaf_prediction
from spotRiver.utils.selectors import select_leaf_model

# %% [markdown]
# ### 1 The Objective Function
#
# * Here we will use the river `HATR` function.
# * First, the function will be tested independently from `Spot`.

# %%
import numpy as np
import datetime as dt
from river import datasets
from river import time_series
from river import utils
import calendar
import math
from river import compose
from river import linear_model
from river import optim
from river import preprocessing
from river import metrics
from spotRiver.fun.hyperriver import HyperRiver

# %% [markdown]
# * Note: Instead of using the Airline Passenger data as in notebook 01, we demonstrate the usage of user specified data which is *not* part of the `spotRiver` package!

# %% [markdown]
# ## River's Synth Data Example

# %%
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np

from river import datasets
from river import evaluate
from river import metrics
from river import preprocessing  # we are going to use that later
from river.datasets import synth  # we are going to use some synthetic datasets too
from river import tree

# %%
from river.datasets import synth
n_samples = 10_000
data = synth.Friedman(seed=42).take(n_samples)
dataset  = list(data)

# %%
# from spotRiver.data.generic import GenericData
# fraction = 1.0
# data = GenericData(filename="opm_num.zip",
#                       directory=".",
#                       target="Sale Amount",
#                       n_features=7,
#                       n_samples=985_862,
#                       fraction = fraction,
#                       converters={'List Year': int,
#                                   'Assessed Value': float,
#                                   'Sale Amount': float,
#                                   'Sales Ratio': float,
#                                   'lon': float,
#                                   'lat': float,
#                                   'timestamp_rec': float},
#                       parse_dates=None
#                       # parse_dates={"Date Recorded": "%Y-%m-%d"}
#                       )
# n_samples = int(data.n_samples * fraction)
# dataset = list(data)

# %%
for x,y in dataset:
    print(x,y)
    break
# Out:
# {0: 0.6394267984578837, 1: 0.025010755222666936, 2: 0.27502931836911926, 3: 0.22321073814882275, 4: 0.7364712141640124, 5: 0.6766994874229113, 6: 0.8921795677048454, 7: 0.08693883262941615, 8: 0.4219218196852704, 9: 0.029797219438070344} 7.6612066799391085

# %%
fun = HyperRiver(123).fun_HTR_iter_progressive
var_type = ["int"] * 2 + ["num"] * 2 + ["factor"] * 2 + ["float"] + ["int"] * 2 + ["factor"] + ["float"]
var_type
# Out:
# ['int',
#  'int',
#  'num',
#  'num',
#  'factor',
#  'factor',
#  'float',
#  'int',
#  'int',
#  'factor',
#  'float']

# %%
var_name=["gracePeriod", "maxDepth", "delta", "tau", "leafPrediction",
          "leafModel", "modelSelDecay", "splitter",
          "minSamplesSplit", "binarySplit", "maxSize"]

# %%
# [[2.00e+02 1.00e+01 1.00e-06 7.50e-02 2.00e+00 1.00e+00 0.00e+00 7.00e+00 0.00e+00 3.12e+02]]
# lower = np.array([100, 1,  1e-8, 0.025, 0, 0, 0.8,  0,  5, 0, 250.0])
# upper = np.array([200, 10, 1e-6, 0.075, 1, 1, 0.975, 1, 10, 1, 750.0])

lower = np.array([100, 1,  1e-8, 0.025, 0, 0, 0.8,  1,  5, 0, 250.0])
upper = np.array([200, 6, 1e-6, 0.075, 0, 1, 0.975, 1, 10, 1, 750.0])
fun_control = {"data": dataset,
               "n_samples": n_samples,
               "weights": np.array([1, 1/10, 1/10])*10_000.0,
               "step": 100,
               "verbosity": 2}

# %% [markdown]
# ### 3 Run the `Spot` Optimizer
#
# * Since the data is larger than the airline passengers data, the max. time is increased.

# %%
spot_htr = spot.Spot(fun=fun,
                   lower = lower,
                   upper = upper,
                   fun_evals = inf,
                   fun_repeats = 1,
                   max_time = 5,
                   noise = False,
                   tolerance_x = np.sqrt(np.spacing(1)),
                   var_type=var_type,
                   var_name=var_name,
                   infill_criterion = "y",
                   n_points = 1,
                   seed=123,
                   log_level = 10,
                   show_models= False,
                   show_progress= True,
                   fun_control = fun_control,
                   design_control={"init_size": 50,
                                   "repeats": 1},
                   surrogate_control={"noise": False,
                                      "cod_type": "norm",
                                      "min_theta": -4,
                                      "max_theta": 3,
                                      "n_theta": 11,
                                      "model_optimizer": differential_evolution,
                                      "model_fun_evals": 1000,
                                      })
spot_htr.run()
# Out:
# grace_period 199
# max_depth 10
# delta 3.422368745191023e-07
# tau 0.03481562818930133
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 5
# binary_split 1
# max_size 412.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 194
# max_depth 100000
# delta 3.6154970089883783e-07
# tau 0.03917575840390259
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 1
# max_size 298.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 142
# max_depth 100
# delta 4.212151986286221e-07
# tau 0.06983409600675924
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 0
# max_size 635.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 167
# max_depth 100000
# delta 9.678144266864377e-07
# tau 0.0290828774274524
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 0
# max_size 567.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 138
# max_depth 10000
# delta 9.148711296663784e-07
# tau 0.0364729579159697
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 0
# max_size 588.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 187
# max_depth 1000
# delta 8.607554719521896e-07
# tau 0.06550329815820466
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 1
# max_size 556.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 163
# max_depth 1000
# delta 3.306497352329033e-08
# tau 0.03038350874858981
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 0
# max_size 544.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 155
# max_depth 100
# delta 4.0555974129918644e-07
# tau 0.07253064921183203
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 0
# max_size 475.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 165
# max_depth 10000
# delta 5.630070566691407e-07
# tau 0.03551161616879678
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 10
# binary_split 0
# max_size 310.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 118
# max_depth 10
# delta 8.318982368543535e-07
# tau 0.03169563890321754
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 5
# binary_split 0
# max_size 747.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 172
# max_depth 100
# delta 3.7322535349518064e-07
# tau 0.037771296545224396
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 1
# max_size 538.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 194
# max_depth 1000
# delta 5.1630963618363e-07
# tau 0.07314140257844065
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 0
# max_size 487.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 127
# max_depth 100
# delta 9.853449315262626e-07
# tau 0.06770681871697895
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 1
# max_size 454.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 111
# max_depth 100000
# delta 3.209599051485644e-07
# tau 0.06403944627162497
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 5
# binary_split 0
# max_size 499.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 181
# max_depth 1000000
# delta 5.986135138874085e-07
# tau 0.052819879053055935
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 1
# max_size 650.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 123
# max_depth 100
# delta 4.459639827230057e-07
# tau 0.03899150383370811
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 0
# max_size 329.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 192
# max_depth 100000
# delta 1.1107060367908053e-07
# tau 0.051539265673927706
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 0
# max_size 263.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 179
# max_depth 1000
# delta 6.846358921068542e-07
# tau 0.040533861241415566
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 5
# binary_split 0
# max_size 521.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 113
# max_depth 1000000
# delta 7.402620815333816e-07
# tau 0.04424054992291482
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 1
# max_size 469.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 151
# max_depth 10
# delta 2.2000216300351304e-07
# tau 0.05919532686248178
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 0
# max_size 730.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 161
# max_depth 100
# delta 5.734707791099132e-07
# tau 0.05475544301916679
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 0
# max_size 330.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 175
# max_depth 1000
# delta 7.639721451472318e-07
# tau 0.06220993362171948
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 1
# max_size 609.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 184
# max_depth 100000
# delta 8.064079957833513e-07
# tau 0.07077047399120398
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 0
# max_size 517.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 184
# max_depth 10
# delta 6.560606499417892e-07
# tau 0.06653824909123643
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 0
# max_size 627.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 190
# max_depth 100000
# delta 6.349000582521553e-07
# tau 0.06008370472442436
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 0
# max_size 285.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 130
# max_depth 10000
# delta 2.829853781766558e-07
# tau 0.025658487958220927
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 1
# max_size 253.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 177
# max_depth 10000
# delta 9.384659257400912e-07
# tau 0.07143832517119383
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 1
# max_size 450.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 154
# max_depth 100000
# delta 7.112985400862688e-07
# tau 0.05556916271718708
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 10
# binary_split 0
# max_size 662.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 129
# max_depth 100
# delta 7.912987308194198e-07
# tau 0.03364281679827083
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 0
# max_size 370.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 106
# max_depth 1000
# delta 1.3956013620074708e-07
# tau 0.041851244188013614
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 0
# max_size 618.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 170
# max_depth 10000
# delta 3.054498284113847e-07
# tau 0.04529461941231694
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 1
# max_size 592.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 125
# max_depth 100000
# delta 8.912493208960708e-07
# tau 0.02899201637194837
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 1
# max_size 409.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 102
# max_depth 1000000
# delta 2.100924883781487e-08
# tau 0.053101286684699406
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 0
# max_size 317.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 144
# max_depth 1000000
# delta 2.389514745390507e-07
# tau 0.04272372654848297
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 1
# max_size 345.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 147
# max_depth 10000
# delta 4.821624382402319e-07
# tau 0.0632795382132108
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 1
# max_size 501.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 108
# max_depth 1000
# delta 7.081199771533676e-08
# tau 0.026335371349752102
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 1
# max_size 273.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 108
# max_depth 1000
# delta 7.623798347107387e-07
# tau 0.06117115807204401
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 1
# max_size 398.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 137
# max_depth 100000
# delta 6.715392730602912e-07
# tau 0.07447629415081207
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 10
# binary_split 1
# max_size 720.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 156
# max_depth 10000
# delta 1.0727528260587241e-07
# tau 0.056808478962171435
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 1
# max_size 677.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 149
# max_depth 1000
# delta 6.30289010927869e-08
# tau 0.04795969701153601
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 10
# binary_split 0
# max_size 363.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 135
# max_depth 10000
# delta 6.223931745823168e-07
# tau 0.0507143476958236
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 1
# max_size 693.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 197
# max_depth 100
# delta 9.53881000577508e-07
# tau 0.06884265159974112
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 0
# max_size 580.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 168
# max_depth 1000
# delta 4.922259828515902e-07
# tau 0.03259292275777353
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 1
# max_size 647.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 116
# max_depth 100
# delta 1.9240991136004873e-07
# tau 0.048841581693307455
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 0
# max_size 385.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 133
# max_depth 100000
# delta 8.640127159786209e-07
# tau 0.04332922549435924
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 10
# binary_split 1
# max_size 352.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 100
# max_depth 10000
# delta 1.528020383560616e-07
# tau 0.05709934024257969
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 0
# max_size 683.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 158
# max_depth 10
# delta 2.550825626564351e-07
# tau 0.05869523149291162
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 1
# max_size 706.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 116
# max_depth 1000000
# delta 5.42632284411268e-07
# tau 0.04958100127193808
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 1
# max_size 436.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 141
# max_depth 100
# delta 4.352633488424992e-07
# tau 0.027289782388737558
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 1
# max_size 421.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 121
# max_depth 10000
# delta 1.7131247099234857e-07
# tau 0.046306247336076495
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 5
# binary_split 1
# max_size 711.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 142
# max_depth 10
# delta 3.263880926434442e-07
# tau 0.03524642671973533
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 1
# max_size 655.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 140g: [----------] 2.50%
# max_depth 1000
# delta 6.111123778863071e-07
# tau 0.03459488788945715
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 0
# max_size 646.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 141g: [----------] 4.80%
# max_depth 10000
# delta 4.1925107947718347e-07
# tau 0.035082313908509896
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 1
# max_size 716.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 141g: [#---------] 6.94%
# max_depth 100
# delta 6.785910133745373e-07
# tau 0.075
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 0
# max_size 594.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 138g: [#---------] 9.20%
# max_depth 100000
# delta 8.121530684397496e-07
# tau 0.04950651829971017
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 0
# max_size 433.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 142g: [#---------] 12.19%
# max_depth 10000
# delta 3.633000802316846e-07
# tau 0.03561756191227167
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 1
# max_size 638.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 145g: [#---------] 14.87%
# max_depth 10000
# delta 1.6393382698080673e-07
# tau 0.07495251556291217
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 10
# binary_split 0
# max_size 617.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 140g: [##--------] 18.09%
# max_depth 100000
# delta 1e-06
# tau 0.025
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 8
# binary_split 0
# max_size 439.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 141g: [##--------] 21.38%
# max_depth 1000000
# delta 8.094450702110867e-07
# tau 0.02675923857838884
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 10
# binary_split 1
# max_size 632.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 142g: [##--------] 24.61%
# max_depth 10
# delta 7.275131153643671e-07
# tau 0.04606679675045877
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 5
# binary_split 0
# max_size 339.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 141g: [###-------] 27.51%
# max_depth 100000
# delta 3.5129453495540817e-07
# tau 0.03167169322811145
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 10
# binary_split 1
# max_size 390.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 137g: [###-------] 30.48%
# max_depth 100000
# delta 1e-06
# tau 0.025
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 9
# binary_split 0
# max_size 436.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 142g: [###-------] 34.65%
# max_depth 10000
# delta 5.201478236876968e-07
# tau 0.05880768267718697
# leaf_prediction mean
# leaf_model LinearRegression
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 7
# binary_split 0
# max_size 742.0
# Eval iter_prog_val_score: [##########] 100.00% Done...
# grace_period 138g: [####------] 37.65%
# max_depth 100000
# delta 1e-06
# tau 0.075
# leaf_prediction mean
# leaf_model Perceptron
# model_selector_decay 1.0
# splitter QOSplitter
# min_samples_split 6
# binary_split 0
# max_size 697.0
# Eval iter_prog_val_score: [##########] 100.00% Done...

# %% [markdown]
# ### 4 Results

# %% [markdown]
# * Show the Progress

# %%
spot_htr.plot_progress(log_y=True)

# %% [markdown]
# * Print the Results

# %%
spot_htr.print_results()

# %%
spot_htr.print_importance()

# %%
min(spot_htr.y), max(spot_htr.y)

# %%
n = spot_htr.k
for i in range(n-1):
    for j in range(i+1, n):
        spot_htr.plot_contour(i=i, j=j, min_z=min(spot_htr.y), max_z = max(spot_htr.y) )

# %% [markdown]
# ## Build and Evaluate HTR Model with Tuned Hyperparameters

# %%
X = spot_htr.to_all_dim(spot_htr.min_X.reshape(1,-1))
print(X)
grace_period = X[:, 0]
max_depth = X[:, 1]
delta = X[:, 2]
tau = X[:, 3]
leaf_prediction = X[:, 4]
leaf_model = X[:, 5]
model_selector_decay = X[:, 6]
splitter = X[:, 7]
min_samples_split = X[:, 8]
binary_split = X[:, 9]
max_size = X[:, 10]

# %%
import numbers
from river import tree
from spotRiver.evaluation.eval_oml import fun_eval_oml_iter_progressive
from spotRiver.evaluation.eval_oml import eval_oml_iter_progressive
from spotRiver.utils.selectors import select_splitter
from spotRiver.utils.selectors import select_max_depth
num = compose.SelectType(numbers.Number) | preprocessing.StandardScaler()
cat = compose.SelectType(str) | preprocessing.FeatureHasher(n_features=1000, seed=1)
res = eval_oml_iter_progressive(
    dataset=fun_control["data"],
    step=fun_control["step"],
    verbose=True,
    metric=metrics.MAE(),
    models={
         "Default: HTR + QO": (
             (num + cat) | tree.HoeffdingTreeRegressor(
                splitter=tree.splitter.QOSplitter()
            )
        ),
        "SPOT: HTR + QO": (
            (num + cat) | tree.HoeffdingTreeRegressor(
                grace_period=int(grace_period),
                max_depth=select_max_depth(int(max_depth)),
                delta=float(delta),
                tau=float(tau),
                leaf_prediction=select_leaf_prediction(int(leaf_prediction)),
                leaf_model=select_leaf_model(int(leaf_model)),
                splitter=select_splitter(int(splitter)),
                min_samples_split=int(min_samples_split),
                binary_split=int(binary_split),
                max_size=float(max_size)
            )
        ),
    }
)
y = fun_eval_oml_iter_progressive(res, metric=None)

# %%
from spotRiver.evaluation.eval_oml import plot_oml_iter_progressive
plot_oml_iter_progressive(res, log_y=False)

# %%
# model
# model["ts"].regressor["lm"].weights
# forecast = model.forecast(horizon=fun_control["horizon"])
# forecast
